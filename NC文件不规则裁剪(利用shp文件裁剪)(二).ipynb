# %%
from osgeo import gdal, ogr, osr
import numpy as np
import xarray as xr
import os
import shutil

# %%
# 打开nc文件
ds = xr.open_dataset(r'air.2m.gauss.2022.nc') # 打开nc文件
out_netCDF = r'air.2m.gauss.2022_clip.nc' # 输出文件名
shp_path = r'ne_10m_coastline/ne_10m_coastline_plog.shp' # 获取shp文件的路径
lat = ds['lat'].values # 获取经纬度
lon = ds['lon'].values # 获取经纬度
air = ds['air'].values # 获取数据
time = ds['time'].values # 获取时间

# %%
# 生成网格信息
# 没有特殊需求的情况下，不需要修改这一段代码
LonMin,LatMax,LonMax,LatMin = [lon.min(),lat.max(),lon.max(),lat.min()]  # 获取经纬度范围
N_Lat = len(lat) # 获取经纬度个数
N_Lon = len(lon) # 获取经纬度个数
Lon_Res = (LonMax - LonMin) /(float(N_Lon)-1) # 获取经纬度分辨率
Lat_Res = (LatMax - LatMin) / (float(N_Lat)-1) # 获取经纬度分辨率

# %%
# 创建一个临时文件夹
# 没有特殊需求的情况下，不需要修改这一段代码
'''
我也不知道为什呢，生成多波段的情况下数据会出错，所以我只能生成多个单波段的tif文件
如果有大佬知道怎么解决，欢迎留言
'''
if not os.path.exists('temporary_folders'):
    os.makedirs('temporary_folders')

for i in range(len(air)):
    out_tif = 'temporary_folders/air.2m.gauss.2022_%s.tif' % i # 生成临时tif文件
    tif_ds = gdal.GetDriverByName('Gtiff').Create(out_tif,N_Lon,N_Lat,1,gdal.GDT_Float32) 
    geotransform = (LonMin,Lon_Res, 0, LatMin, 0, Lat_Res) # 设置栅格数据的左上角的经度坐标，经度分辨率，旋转角度，左上角的纬度坐标，纬度分辨率，旋转角度
    tif_ds.SetGeoTransform(geotransform) # 设置栅格数据的地理参考信息
    srs = osr.SpatialReference() # 创建坐标系
    srs.ImportFromEPSG(4326) # 定义地理坐标系统为WGS84(4326代表WGS84)
    tif_ds.SetProjection(srs.ExportToWkt()) # 设置栅格数据的坐标系
    tif_ds.GetRasterBand(1).WriteArray(air[i,:,:]) # 写入数据
    tif_ds.FlushCache() # 将数据写入文件

# %%
temporary_folders_files = os.listdir('temporary_folders') # 获取临时文件夹下的文件
temporary_folders_files = [os.path.join('temporary_folders',i) for i in temporary_folders_files] # 获取临时文件夹下的文件路径



if not os.path.exists('temporary_folders_clip'):
    os.makedirs('temporary_folders_clip')

for i in range(len(temporary_folders_files)):
    # ds = gdal.Open(temporary_folders_files[i]) # 打开刚刚输出的tif文件
    # print(temporary_folders_files[i])
    print(r'temporary_folders_clip/air.2m.gauss.2022_clip_%s.tif' % i)
    
    # 使用shp裁剪
    ds = gdal.Warp(
    r'temporary_folders_clip/air.2m.gauss.2022_clip_%s.tif' % i, #待裁剪的影像完整路径（包括文件名）
    temporary_folders_files[i],    #裁剪后图像保存的完整路径（包括文件名）
    format='GTiff', # 保存图像的格式
    cutlineDSName=shp_path, # 矢量文件的完整路径
    cropToCutline=True, # 保证裁剪后影像大小跟矢量文件的图框大小一致（设置为False时，结果图像大小会跟待裁剪影像大小一样，则会出现大量的空值区域）
    # cutlineWhere=cutlineWhere, #矢量文件筛选条件,
    dstNodata=np.nan, #设置空值
    )
ds = None # 关闭文件
# Out:
# temporary_folders_clip/air.2m.gauss.2022_clip_0.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_1.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_2.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_3.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_4.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_5.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_6.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_7.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_8.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_9.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_10.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_11.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_12.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_13.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_14.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_15.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_16.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_17.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_18.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_19.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_20.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_21.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_22.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_23.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_24.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_25.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_26.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_27.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_28.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_29.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_30.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_31.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_32.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_33.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_34.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_35.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_36.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_37.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_38.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_39.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_40.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_41.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_42.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_43.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_44.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_45.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_46.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_47.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_48.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_49.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_50.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_51.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_52.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_53.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_54.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_55.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_56.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_57.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_58.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_59.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_60.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_61.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_62.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_63.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_64.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_65.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_66.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_67.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_68.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_69.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_70.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_71.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_72.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_73.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_74.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_75.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_76.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_77.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_78.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_79.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_80.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_81.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_82.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_83.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_84.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_85.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_86.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_87.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_88.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_89.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_90.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_91.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_92.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_93.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_94.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_95.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_96.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_97.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_98.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_99.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_100.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_101.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_102.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_103.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_104.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_105.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_106.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_107.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_108.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_109.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_110.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_111.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_112.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_113.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_114.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_115.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_116.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_117.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_118.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_119.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_120.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_121.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_122.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_123.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_124.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_125.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_126.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_127.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_128.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_129.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_130.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_131.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_132.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_133.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_134.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_135.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_136.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_137.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_138.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_139.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_140.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_141.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_142.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_143.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_144.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_145.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_146.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_147.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_148.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_149.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_150.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_151.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_152.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_153.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_154.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_155.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_156.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_157.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_158.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_159.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_160.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_161.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_162.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_163.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_164.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_165.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_166.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_167.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_168.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_169.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_170.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_171.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_172.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_173.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_174.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_175.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_176.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_177.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_178.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_179.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_180.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_181.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_182.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_183.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_184.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_185.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_186.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_187.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_188.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_189.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_190.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_191.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_192.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_193.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_194.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_195.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_196.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_197.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_198.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_199.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_200.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_201.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_202.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_203.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_204.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_205.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_206.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_207.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_208.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_209.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_210.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_211.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_212.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_213.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_214.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_215.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_216.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_217.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_218.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_219.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_220.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_221.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_222.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_223.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_224.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_225.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_226.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_227.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_228.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_229.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_230.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_231.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_232.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_233.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_234.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_235.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_236.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_237.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_238.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_239.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_240.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_241.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_242.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_243.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_244.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_245.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_246.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_247.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_248.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_249.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_250.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_251.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_252.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_253.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_254.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_255.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_256.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_257.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_258.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_259.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_260.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_261.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_262.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_263.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_264.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_265.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_266.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_267.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_268.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_269.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_270.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_271.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_272.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_273.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_274.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_275.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_276.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_277.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_278.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_279.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_280.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_281.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_282.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_283.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_284.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_285.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_286.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_287.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_288.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_289.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_290.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_291.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_292.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_293.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_294.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_295.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_296.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_297.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_298.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_299.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_300.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_301.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_302.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_303.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_304.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_305.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_306.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_307.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_308.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_309.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_310.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_311.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_312.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_313.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_314.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_315.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_316.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_317.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_318.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_319.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_320.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_321.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_322.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_323.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_324.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_325.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_326.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_327.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_328.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_329.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_330.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_331.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_332.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_333.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_334.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_335.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_336.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_337.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_338.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_339.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_340.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_341.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_342.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_343.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_344.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_345.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_346.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_347.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_348.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_349.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_350.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_351.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_352.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_353.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_354.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_355.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_356.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_357.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_358.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_359.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_360.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_361.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_362.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_363.tif
# temporary_folders_clip/air.2m.gauss.2022_clip_364.tif

# %%
# 重新生成NC文件

file_list = os.listdir('temporary_folders_clip') # 获取裁剪后的tif文件
file_list = [os.path.join('temporary_folders_clip',i) for i in file_list] # 获取裁剪后的tif文件路径
file_list

ds0 = gdal.Open(file_list[0]) # 打开第一个tif文件
data = ds0.ReadAsArray() # 读取数据
geotransform = ds0.GetGeoTransform() # 获取栅格数据的地理参考信息
num_x = ds0.RasterXSize # 获取栅格数据的列数
num_y = ds0.RasterYSize # 获取栅格数据的行数

print(num_x,num_y,'\n',geotransform)
# Out:
# 32 27
#  (75.0, 1.875, 0.0, 54.267677307128906, 0.0, -1.9041290283203125)

# %%
# 生成网格信息
# 没有特殊需求的情况下，不需要修改这一段代码

lon = np.arange(geotransform[0],geotransform[0]+num_x*geotransform[1],geotransform[1]) # 生成经度

lat = np.arange(geotransform[3],geotransform[3]+num_y*geotransform[5],geotransform[5]) # 生成纬度

air_clip_nc = np.zeros((len(file_list),num_y,num_x)) # 生成一个空数组

# 获取数据
ds0_data = ds0.ReadAsArray() # 读取数据

# 获取array的序列
index_ = int(file_list[0].split('_')[-1].split('.')[0])
air_clip_nc[index_,:,:] = ds0_data

# %%
for i in range(1,len(file_list)):
    ds = gdal.Open(file_list[i]) # 打开tif文件
    ds_data = ds.ReadAsArray() # 读取数据
    index_ = int(file_list[i].split('_')[-1].split('.')[0])
    air_clip_nc[index_,:,:] = ds_data
    ds = None # 关闭文件

# 生成nc文件
result_nc = xr.Dataset()
result_nc['air'] = xr.DataArray(air_clip_nc,coords=[('time',time),('lat',lat),('lon',lon)],dims=['time','lat','lon'])
result_nc['air'].attrs['long_name'] = 'air'
result_nc['air'].attrs['units'] = 'K'
result_nc['air'].attrs['standard_name'] = '2m_air_temperature'
result_nc['lon'].attrs['long_name'] = 'longitude'
result_nc['lon'].attrs['units'] = 'degrees_east'
result_nc['lon'].attrs['standard_name'] = 'longitude'
result_nc['lat'].attrs['long_name'] = 'latitude'
result_nc['lat'].attrs['units'] = 'degrees_north'
result_nc['lat'].attrs['standard_name'] = 'latitude'
result_nc['time'].attrs['long_name'] = 'time'

result_nc.to_netcdf(out_netCDF) # 保存nc文件

# 删除临时文件夹
try:
    shutil.rmtree('temporary_folders_clip')
    shutil.rmtree('temporary_folders')
except PermissionError:
    print('请关闭Python后手动删除临时文件夹')
    # 通常情况下，temporary_folders文件夹最后一个文件会被占用，无法删除，此时需要手动删除
    # 但是不影响裁剪程序的运行
    # 关闭python之后手动删除一下啦
    pass
# Out:
# 请关闭Python后手动删除临时文件夹
